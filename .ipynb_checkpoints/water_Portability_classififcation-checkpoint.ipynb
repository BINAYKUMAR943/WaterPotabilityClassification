# %%
import pandas as pd

# %%
wp_data=pd.read_csv("D:/UEA/Kaggle Practice/water_potability.csv")

# %%
wp_data.head(5)
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
wp_data.shape
# Out:
# (3276, 10)

# %%
wp_data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
wp_data.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# Hardness            -0.023915        0.003610        -0.013013  -0.014449
# Solids               0.013831        0.010242        -0.009143   0.019546
# Chloramines         -0.020486       -0.012653         0.017084   0.002363
# Sulfate             -0.016121        0.030831        -0.030274  -0.011187
# Conductivity         1.000000        0.020966         0.001285   0.005798
# Organic_carbon       0.020966        1.000000        -0.013274  -0.027308
# Trihalomethanes      0.001285       -0.013274         1.000000  -0.022145
# Turbidity            0.005798       -0.027308        -0.022145   1.000000
# Potability          -0.008128       -0.030001         0.007130   0.001581
#
#                  Potability
# ph                -0.003556
# Hardness          -0.013837
# Solids             0.033743
# Chloramines        0.023779
# Sulfate           -0.023577
# Conductivity      -0.008128
# Organic_carbon    -0.030001
# Trihalomethanes    0.007130
# Turbidity          0.001581
# Potability         1.000000

# %%
#Normazing the data to use knn imputer to handle missing values
wp_data.isnull().sum()/wp_data.shape[0]
# Out:
# ph                 0.149878
# Hardness           0.000000
# Solids             0.000000
# Chloramines        0.000000
# Sulfate            0.238400
# Conductivity       0.000000
# Organic_carbon     0.000000
# Trihalomethanes    0.049451
# Turbidity          0.000000
# Potability         0.000000
# dtype: float64

# %%
X=wp_data.iloc[:,0:9]

# %%
y=wp_data.iloc[:,-1]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Potability, dtype: int64

# %%
X.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       10.379783        86.990970   2.963135
# 1       15.180013        56.329076   4.500656
# 2       16.868637        66.420093   3.055934
# 3       18.436524       100.341674   4.628771
# 4       11.558279        31.997993   4.075075

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline

# %%
def optimize_k(X, y):
    errors = []
    for k in range(1, 20, 1):
        imputer = KNNImputer(n_neighbors=k)
        imputed = imputer.fit_transform(data)
        df_imputed = pd.DataFrame(imputed, columns=data.columns)
        
       # X = df_imputed.drop(target, axis=1)
       # y = df_imputed[target]
        X_train, X_test, y_train, y_test = train_test_split(df_imputed, y, test_size=0.2, random_state=42)

        model = RandomForestClassifier()
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        accuracy_scores= accuracy_score(y_test, preds)
        accuracy_scores.append({'K': k, 'accuracy': error})
        
    return acuuracy

# %%
scaler = StandardScaler()
scaled_data_for_imput=scaler.fit_transform(X)
scaled_Input_df=pd.DataFrame(scaled_data_for_imput,columns=wp_data.columns)

# %%
scaled_dataFrame
# Out:
#             ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 0          NaN  0.259195 -0.139471     0.112415  0.838973      1.708954
# 1    -2.110818 -2.036414 -0.385987    -0.307694       NaN      2.062575
# 2     0.638838  0.847665 -0.240047     1.360594       NaN     -0.094032
# 3     0.775374  0.547651  0.000493     0.592008  0.558106     -0.778830
# 4     1.261849 -0.464429 -0.460249    -0.363698 -0.570898     -0.343939
# ...        ...       ...       ...          ...       ...           ...
# 3271 -1.513577 -0.081758  2.916188     0.028027  0.632063      1.240155
# 3272  0.456742 -0.085667 -0.534295     0.593290       NaN     -0.417706
# 3273  1.467169 -0.626829  1.270810     0.144017       NaN      0.072263
# 3274 -1.225841  1.041355 -1.144058    -0.517373       NaN     -0.288597
# 3275  0.498030 -0.038546 -0.525812     0.244515       NaN     -1.221919
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0          -1.180651         1.273445  -1.286298   -0.799775
# 1           0.270597        -0.622493   0.684218   -0.799775
# 2           0.781117         0.001472  -1.167365   -0.799775
# 3           1.255134         2.098969   0.848412   -0.799775
# 4          -0.824357        -2.126974   0.138786   -0.799775
# ...              ...              ...        ...         ...
# 3271       -0.118075         0.018018   0.601124    1.250352
# 3272        1.698560              NaN  -1.497627    1.250352
# 3273       -0.981329         0.213271  -0.856007    1.250352
# 3274       -0.942064         0.685854   0.950797    1.250352
# 3275        0.560940         0.760688  -2.124459    1.250352
#
# [3276 rows x 10 columns]

# %%
optimized_k=optimize_k(scaled_Input_df,y)
optimized_k
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-2ce22f32e1a5> in <module>
# ----> 1 optimized_k=optimize_k(scaled_dataFrame,"Potability")
#       2 optimized_k
#
# <ipython-input-56-3e0f2f986fe2> in optimize_k(data, target)
#      11
#      12         model = RandomForestClassifier()
# ---> 13         model.fit(X_train, y_train)
#      14         preds = model.predict(X_test)
#      15         accuracy_scores= accuracy_score(y_test, preds)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         self.n_outputs_ = y.shape[1]
#     330
# --> 331         y, expanded_class_weight = self._validate_y_class_weight(y)
#     332
#     333         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     557
#     558     def _validate_y_class_weight(self, y):
# --> 559         check_classification_targets(y)
#     560
#     561         y = np.copy(y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
optimized_k
# Out:
# [{'K': 1, 'RMSE': 0.7775926427715931},
#  {'K': 2, 'RMSE': 0.8070682420826871},
#  {'K': 3, 'RMSE': 0.8158241064492869},
#  {'K': 4, 'RMSE': 0.821457818974935},
#  {'K': 5, 'RMSE': 0.811203347352849},
#  {'K': 6, 'RMSE': 0.8205832576650851},
#  {'K': 7, 'RMSE': 0.8174226635687558},
#  {'K': 8, 'RMSE': 0.8134035257689843},
#  {'K': 9, 'RMSE': 0.8230301072198958},
#  {'K': 10, 'RMSE': 0.8245889406754744},
#  {'K': 11, 'RMSE': 0.8231479968030553},
#  {'K': 12, 'RMSE': 0.8216916760284845},
#  {'K': 13, 'RMSE': 0.8114974306064909},
#  {'K': 14, 'RMSE': 0.8281896985958819},
#  {'K': 15, 'RMSE': 0.8179429154248717},
#  {'K': 16, 'RMSE': 0.8257005625601554},
#  {'K': 17, 'RMSE': 0.8113507093317983},
#  {'K': 18, 'RMSE': 0.8027441290569167},
#  {'K': 19, 'RMSE': 0.8198541362214156}]

# %%
myPipe=Pipeline(steps=[('scaler',StandardScaler()),('knnImputer',KNNImputer(n_neighbors=5)),('rfc',RandomForestClassifier()),])
